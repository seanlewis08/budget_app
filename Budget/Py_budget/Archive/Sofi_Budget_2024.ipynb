# %%
from datetime import datetime as dt  #to manipulate dates

import numpy as np  #to cleanse data
import openpyxl
import pandas as pd
import plotly.express as px  #to create interactive charts
import plotly.graph_objects as go  #to create interactive charts
from datetime import datetime

# %%
dtype_dict = {
    'Description': 'string',
    'Amount': 'float',
    'Type': 'string',
    'Current balance': 'float',
    'Status': 'string'
}

ytd_data = pd.read_csv(
    'D:\\Sean\\Documents\\Personal\\Budget\\YTD_downloads\\2024\\SOFI-Savings.csv', dtype=dtype_dict, parse_dates=['Date']
)


ytd_data['Account'] = 'sofi_savings'
ytd_data.rename(columns={'Date':'Trans. Date','Current balance':'CumAmount'}, inplace=True)

ytd_data['Date'] = pd.to_datetime(ytd_data['Trans. Date'].dt.strftime('%m/%Y'), format='%m/%Y')

# %%
ytd_data
# Out:
#     Trans. Date         Description             Type   Amount  CumAmount  \
# 0    2024-12-31     Interest earned  Interest Earned    12.43    5075.54
# 1    2024-12-23          Nationwide   Direct Deposit  2989.48    5063.11
# 2    2024-12-16            DISCOVER   Direct Payment -2386.27    2073.63
# 3    2024-12-13  To Checking - 8930       Withdrawal -1132.00    4459.90
# 4    2024-12-13  To Checking - 8930       Withdrawal  -155.00    5591.90
# ..          ...                 ...              ...      ...        ...
# 123  2024-01-23  To Checking - 8930       Withdrawal  -155.00    2259.86
# 124  2024-01-16    BOARD OF REGENTS   Direct Payment  -932.00    2414.86
# 125  2024-01-11            DISCOVER   Direct Payment -1382.28    3346.86
# 126  2024-01-09          Nationwide   Direct Deposit  2845.53    4729.14
# 127  2024-01-02            DISCOVER   Direct Payment -1568.14    1883.61
#
#      Status       Account       Date
# 0    Posted  sofi_savings 2024-12-01
# 1    Posted  sofi_savings 2024-12-01
# 2    Posted  sofi_savings 2024-12-01
# 3    Posted  sofi_savings 2024-12-01
# 4    Posted  sofi_savings 2024-12-01
# ..      ...           ...        ...
# 123  Posted  sofi_savings 2024-01-01
# 124  Posted  sofi_savings 2024-01-01
# 125  Posted  sofi_savings 2024-01-01
# 126  Posted  sofi_savings 2024-01-01
# 127  Posted  sofi_savings 2024-01-01
#
# [128 rows x 8 columns]

# %%
# Discover Transactions
mapping = {
    # Direct Deposit
    'income': ['PAYROLL', "Nationwide",'Franchise Tax BD', 'IRS  TREAS 310'],
    'interest': ['INTEREST'],
    'school':['BOARD OF REGENTS'],
    'transfer' :['TRANSFER','To Checking - 8930','Discover','WELLS FARGO BANK','WELLS FARGO IFI'],
    'Don': ['Fortiva']

    
    
}
for k, v in mapping.items():
    ytd_data.loc[ytd_data.Description.str.contains('|'.join(v), case=False), 'Short_Desc'] = k
    ytd_data.loc[ytd_data.Description.str.contains("WELLS FARGO BANK", case=False) & (
            ytd_data['Amount'] == -2100), 'Short_Desc'] = 'family'

# %%
ytd_data[ytd_data['Short_Desc'].isnull()].sort_values(by='Amount', ascending=False)
# Out:
# Empty DataFrame
# Columns: [Trans. Date, Description, Type, Amount, CumAmount, Status, Account, Date, Short_Desc]
# Index: []

# %%
ytd_data.loc[ytd_data['Short_Desc'].isnull(), 'Short_Desc'] = 'unsure'

# %%
reocurring_list = []
ytd_data.loc[ytd_data.Short_Desc.isin(reocurring_list), 'Reoccurring_Flag'] = 'Yes'
ytd_data.loc[~ytd_data.Short_Desc.isin(reocurring_list), 'Reoccurring_Flag'] = 'No'

mapping = {
    'Housing': [],
    'Transportation': [],
    'Food': [],
    'Insurance': [],
    'Utilities': [],
    'Medical': [],
    'Government': [],
    'Savings': ['income'],
    'Personal_Spending': ['school'],
    'Recreation_Entertainment': [],
    'Misc': [],
    'People': ['family'],
    'Payment_and_Interest': ['interest']
}

for k, v in mapping.items():
    ytd_data.loc[ytd_data.Short_Desc.isin(v), 'Category_2'] = k

# %%
ytd_data[ytd_data['Category_2'].isnull()].sort_values(by='Description', ascending=False).sort_values(by='Short_Desc',
                                                                                                     ascending=False)
# Out:
#     Trans. Date         Description            Type   Amount  CumAmount  \
# 42   2024-07-28     WELLS FARGO IFI         Deposit  3500.00    5454.07
# 28   2024-09-13  To Checking - 8930      Withdrawal  -155.00    3881.65
# 104  2024-03-01  To Checking - 8930      Withdrawal  -450.00     585.91
# 52   2024-07-21  To Checking - 8930      Withdrawal -2000.00    2446.82
# 47   2024-07-23  To Checking - 8930      Withdrawal -1600.00    3836.30
# ..          ...                 ...             ...      ...        ...
# 79   2024-05-13  To Checking - 8930      Withdrawal  -155.00    2182.50
# 77   2024-05-18  To Checking - 8930      Withdrawal -1640.00    3531.98
# 73   2024-06-01  To Checking - 8930      Withdrawal  -450.00    4718.64
# 113  2024-02-08  To Checking - 8930      Withdrawal  -820.00     529.18
# 43   2024-07-26         Fortiva PMT  Direct Payment  -248.63    1954.07
#
#      Status       Account       Date Short_Desc Reoccurring_Flag Category_2
# 42   Posted  sofi_savings 2024-07-01   transfer               No        NaN
# 28   Posted  sofi_savings 2024-09-01   transfer               No        NaN
# 104  Posted  sofi_savings 2024-03-01   transfer               No        NaN
# 52   Posted  sofi_savings 2024-07-01   transfer               No        NaN
# 47   Posted  sofi_savings 2024-07-01   transfer               No        NaN
# ..      ...           ...        ...        ...              ...        ...
# 79   Posted  sofi_savings 2024-05-01   transfer               No        NaN
# 77   Posted  sofi_savings 2024-05-01   transfer               No        NaN
# 73   Posted  sofi_savings 2024-06-01   transfer               No        NaN
# 113  Posted  sofi_savings 2024-02-01   transfer               No        NaN
# 43   Posted  sofi_savings 2024-07-01        Don               No        NaN
#
# [85 rows x 11 columns]

# %%
x = ytd_data.groupby(['Reoccurring_Flag']).size().reset_index(name='count')

x.sort_values(by='count', ascending=False)
# Out:
#   Reoccurring_Flag  count
# 0               No    128

# %%
ytd_sorted = ytd_data.sort_values(by='Trans. Date').reset_index(drop=True)

# Ensure 'Sort_Date' is also in datetime format for the entire DataFrame
ytd_sorted['Trans. Date'] = pd.to_datetime(ytd_sorted['Trans. Date'])
ytd_sorted['Year'] = ytd_sorted['Trans. Date'].dt.year
ytd_sorted['Counter'] = ytd_sorted.groupby('Short_Desc').cumcount() + 1
ytd_sorted
# Out:
#     Trans. Date         Description             Type   Amount  CumAmount  \
# 0    2024-01-02            DISCOVER   Direct Payment -1568.14    1883.61
# 1    2024-01-09          Nationwide   Direct Deposit  2845.53    4729.14
# 2    2024-01-11            DISCOVER   Direct Payment -1382.28    3346.86
# 3    2024-01-16    BOARD OF REGENTS   Direct Payment  -932.00    2414.86
# 4    2024-01-23          Nationwide   Direct Deposit  2845.53    5105.39
# ..          ...                 ...              ...      ...        ...
# 123  2024-12-13  To Checking - 8930       Withdrawal  -155.00    5591.90
# 124  2024-12-13  To Checking - 8930       Withdrawal -1132.00    4459.90
# 125  2024-12-16            DISCOVER   Direct Payment -2386.27    2073.63
# 126  2024-12-23          Nationwide   Direct Deposit  2989.48    5063.11
# 127  2024-12-31     Interest earned  Interest Earned    12.43    5075.54
#
#      Status       Account       Date Short_Desc Reoccurring_Flag  \
# 0    Posted  sofi_savings 2024-01-01   transfer               No
# 1    Posted  sofi_savings 2024-01-01     income               No
# 2    Posted  sofi_savings 2024-01-01   transfer               No
# 3    Posted  sofi_savings 2024-01-01     school               No
# 4    Posted  sofi_savings 2024-01-01     income               No
# ..      ...           ...        ...        ...              ...
# 123  Posted  sofi_savings 2024-12-01   transfer               No
# 124  Posted  sofi_savings 2024-12-01   transfer               No
# 125  Posted  sofi_savings 2024-12-01   transfer               No
# 126  Posted  sofi_savings 2024-12-01     income               No
# 127  Posted  sofi_savings 2024-12-01   interest               No
#
#                Category_2  Year  Counter
# 0                     NaN  2024        1
# 1                 Savings  2024        1
# 2                     NaN  2024        2
# 3       Personal_Spending  2024        1
# 4                 Savings  2024        2
# ..                    ...   ...      ...
# 123                   NaN  2024       82
# 124                   NaN  2024       83
# 125                   NaN  2024       84
# 126               Savings  2024       28
# 127  Payment_and_Interest  2024       12
#
# [128 rows x 13 columns]

# %%
columns = ['Trans. Date', 'Description', 'Amount', 'Category', 'Short_Desc', 'Reoccurring_Flag',
                     'Category_2', 'Date', 'Year', 'Sort_Date', 'CumAmount', 'Counter', 'Account']
ytd_sorted['Category'] = 'NA'
ytd_sorted['Sort_Date'] = ytd_sorted['Trans. Date']

sofi_svaings = ytd_sorted[columns]

# %%
sofi_svaings.to_excel('D:\\Sean\\Documents\\Personal\\Budget\\2024_output\\sofi_savings_Curated_Bills.xlsx')
