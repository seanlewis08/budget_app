# %%
# Bills for Quick purchases
ytd_data.loc[ytd_data.Description.str.contains("walgreens", case=False), 'Short_Desc'] = 'conv_store'
ytd_data.loc[ytd_data.Description.str.contains("cvs", case=False), 'Short_Desc'] = 'conv_store'
ytd_data.loc[ytd_data.Description.str.contains("7-eleven", case=False), 'Short_Desc'] = 'conv_store'
ytd_data.loc[ytd_data.Description.str.contains("7-eleven", case=False), 'Short_Desc'] = 'conv_store'
ytd_data.loc[ytd_data.Description.str.contains("staples", case=False), 'Short_Desc'] = 'staples'
ytd_data.loc[ytd_data.Description.str.contains("target", case=False), 'Short_Desc'] = 'target'
ytd_data.loc[ytd_data.Description.str.contains("walmart", case=False), 'Short_Desc'] = 'walmart'
ytd_data.loc[ytd_data.Description.str.contains("DCA", case=False), 'Short_Desc'] = 'airport'
ytd_data.loc[ytd_data.Description.str.contains("faber news", case=False), 'Short_Desc'] = 'airport'
ytd_data.loc[ytd_data.Description.str.contains("vending", case=False), 'Short_Desc'] = 'vending'

# Bills for fun
ytd_data.loc[ytd_data.Description.str.contains("oculus", case=False), 'Short_Desc'] = 'oculus'
ytd_data.loc[ytd_data.Description.str.contains("widmo", case=False), 'Short_Desc'] = 'oculus'
ytd_data.loc[ytd_data.Description.str.contains("gauss labs", case=False), 'Short_Desc'] = 'oculus'
ytd_data.loc[ytd_data.Description.str.contains("onlyfans", case=False), 'Short_Desc'] = 'onlyfans'
ytd_data.loc[ytd_data.Description.str.contains("ccbill", case=False), 'Short_Desc'] = 'onlyfans'
ytd_data.loc[ytd_data.Description.str.contains("corinne", case=False), 'Short_Desc'] = 'concert'
ytd_data.loc[ytd_data.Description.str.contains("the van buren", case=False), 'Short_Desc'] = 'concert'
ytd_data.loc[ytd_data.Description.str.contains("fleet", case=False), 'Short_Desc'] = 'concert'
ytd_data.loc[ytd_data.Description.str.contains("phoenix performing", case=False), 'Short_Desc'] = 'concert'
ytd_data.loc[ytd_data.Description.str.contains("moore theater", case=False), 'Short_Desc'] = 'concert'
ytd_data.loc[ytd_data.Description.str.contains("frontgate", case=False), 'Short_Desc'] = 'music_festival'
ytd_data.loc[ytd_data.Description.str.contains("festival", case=False), 'Short_Desc'] = 'music_festival'
ytd_data.loc[ytd_data.Description.str.contains("innings", case=False), 'Short_Desc'] = 'music_festival'
ytd_data.loc[ytd_data.Description.str.contains("stand up", case=False), 'Short_Desc'] = 'comedy'
ytd_data.loc[ytd_data.Description.str.contains("suns", case=False), 'Short_Desc'] = 'live_nba'
ytd_data.loc[ytd_data.Description.str.contains("planned parent", case=False), 'Short_Desc'] = 'political_cause'
ytd_data.loc[ytd_data.Description.str.contains("zoo", case=False), 'Short_Desc'] = 'zoo'
ytd_data.loc[ytd_data.Description.str.contains("dicks", case=False), 'Short_Desc'] = 'sport_stuff'
ytd_data.loc[ytd_data.Description.str.contains("amc", case=False), 'Short_Desc'] = 'movies'
ytd_data.loc[ytd_data.Description.str.contains("ati", case=False), 'Short_Desc'] = 'movies'
ytd_data.loc[ytd_data.Description.str.contains("theatre", case=False), 'Short_Desc'] = 'movies'
ytd_data.loc[ytd_data.Description.str.contains("diamond", case=False), 'Short_Desc'] = 'live_baseball'
ytd_data.loc[ytd_data.Description.str.contains("chihuly", case=False), 'Short_Desc'] = 'museum'
ytd_data.loc[ytd_data.Description.str.contains("musical instrument", case=False), 'Short_Desc'] = 'museum'
ytd_data.loc[ytd_data.Description.str.contains("botanical", case=False), 'Short_Desc'] = 'museum'
ytd_data.loc[ytd_data.Description.str.contains("grand c", case=False), 'Short_Desc'] = 'museum'
ytd_data.loc[ytd_data.Description.str.contains("see tickets", case=False), 'Short_Desc'] = 'concerts'
ytd_data.loc[ytd_data.Description.str.contains("jacob collier", case=False), 'Short_Desc'] = 'concerts'
ytd_data.loc[ytd_data.Description.str.contains("fandango", case=False), 'Short_Desc'] = 'movies'
ytd_data.loc[ytd_data.Description.str.contains("life time", case=False), 'Short_Desc'] = 'gym'
ytd_data.loc[ytd_data.Description.str.contains("space needle", case=False), 'Short_Desc'] = 'museum'
ytd_data.loc[ytd_data.Description.str.contains("mens wearhouse", case=False), 'Short_Desc'] = 'clothes'
ytd_data.loc[ytd_data.Description.str.contains("ritt Momney", case=False), 'Short_Desc'] = 'concert'
ytd_data.loc[ytd_data.Description.str.contains("usta", case=False), 'Short_Desc'] = 'tennis'
ytd_data.loc[ytd_data.Description.str.contains("autozone", case=False), 'Short_Desc'] = 'car'
ytd_data.loc[ytd_data.Description.str.contains("casper", case=False), 'Short_Desc'] = 'home'
ytd_data.loc[ytd_data.Description.str.contains("unlv web", case=False), 'Short_Desc'] = 'live_nba'
ytd_data.loc[ytd_data.Description.str.contains("QUINTEVENTS", case=False), 'Short_Desc'] = 'live_nba'
ytd_data.loc[ytd_data.Description.str.contains("a-z tennis", case=False), 'Short_Desc'] = 'tennis'
ytd_data.loc[ytd_data.Description.str.contains("hoover dam", case=False), 'Short_Desc'] = 'hoover_dam'
ytd_data.loc[ytd_data.Description.str.contains("steam", case=False), 'Short_Desc'] = 'video_games'
ytd_data.loc[ytd_data.Description.str.contains("showtime", case=False), 'Short_Desc'] = 'live_event'
ytd_data.loc[ytd_data.Description.str.contains("r u 4 real", case=False), 'Short_Desc'] = 'vr_arcade'
ytd_data.loc[ytd_data.Description.str.contains("AKCHIN PAVILION AMPHI PHOENIX AZ", case=False), 'Short_Desc'] = 'concert'


#Bills for personal items (clothing etc)
ytd_data.loc[ytd_data.Description.str.contains("famous footwear", case=False), 'Short_Desc'] = 'clothing'
ytd_data.loc[ytd_data.Description.str.contains("foot locker", case=False), 'Short_Desc'] = 'clothing'
ytd_data.loc[ytd_data.Description.str.contains("ross", case=False), 'Short_Desc'] = 'clothing'
ytd_data.loc[ytd_data.Description.str.contains("straw and wool", case=False), 'Short_Desc'] = 'clothing'
ytd_data.loc[ytd_data.Description.str.contains("rei", case=False), 'Short_Desc'] = 'clothing'
ytd_data.loc[ytd_data.Description.str.contains("unlv tmc", case=False), 'Short_Desc'] = 'clothing'
ytd_data.loc[ytd_data.Description.str.contains("minter goods", case=False), 'Short_Desc'] = 'wallet'
ytd_data.loc[ytd_data.Description.str.contains("simply seattle", case=False), 'Short_Desc'] = 'clothing'
ytd_data.loc[ytd_data.Description.str.contains("waba hair", case=False), 'Short_Desc'] = 'hair_supplies'
ytd_data.loc[ytd_data.Description.str.contains("h&m", case=False), 'Short_Desc'] = 'clothing'
ytd_data.loc[ytd_data.Description.str.contains("home depot", case=False), 'Short_Desc'] = 'home_supplies'
ytd_data.loc[ytd_data.Description.str.contains("gdp\*vimraj", case=False), 'Short_Desc'] = 'clothing'
ytd_data.loc[ytd_data.Description.str.contains("bonobos", case=False), 'Short_Desc'] = 'clothing'

# Bills for learning
ytd_data.loc[ytd_data.Description.str.contains("datacamp", case=False), 'Short_Desc'] = 'learning'
ytd_data.loc[ytd_data.Description.str.contains("interactive", case=False), 'Short_Desc'] = 'learning'
ytd_data.loc[ytd_data.Description.str.contains("book", case=False), 'Short_Desc'] = 'bookstore'
ytd_data.loc[ytd_data.Description.str.contains("udemy", case=False), 'Short_Desc'] = 'learning'
ytd_data.loc[ytd_data.Description.str.contains("linkedin", case=False), 'Short_Desc'] = 'professional'
ytd_data.loc[ytd_data.Description.str.contains("transcript", case=False), 'Short_Desc'] = 'learning'
ytd_data.loc[ytd_data.Description.str.contains("\*play", case=False), 'Short_Desc'] = 'learning'
ytd_data.loc[ytd_data.Description.str.contains("dataspell", case=False), 'Short_Desc'] = 'professional'

# Bills for medical services
ytd_data.loc[ytd_data.Description.str.contains("banner", case=False), 'Short_Desc'] = 'medical'

#Unsure
#ytd_data.loc[ytd_data.Description.str.contains("tony", case=False), 'Short_Desc'] = 'unsure'
#ytd_data.loc[ytd_data.Description.str.contains("caapple", case=False)& (ytd_data.Amount == 26.49), 'Short_Desc'] = 'unsure'
#ytd_data.loc[ytd_data.Description.str.contains("caapple", case=False)& (ytd_data.Amount == 9.75), 'Short_Desc'] = 'unsure'
#ytd_data.loc[ytd_data.Description.str.contains("caapple", case=False)& (ytd_data.Amount == 8.00), 'Short_Desc'] = 'unsure'

#August
ytd_data.loc[ytd_data.Description.str.contains("FOGO", case=False), 'Short_Desc'] = 'restaurant'
ytd_data.loc[ytd_data.Description.str.contains("GA TECH", case=False), 'Short_Desc'] = 'learning'
ytd_data.loc[ytd_data.Description.str.contains("FOGO", case=False), 'Short_Desc'] = 'restaurant'
ytd_data.loc[ytd_data.Description.str.contains("THE THEODORE PHOENIX AZ", case=False), 'Short_Desc'] = 'restaurant'
ytd_data.loc[ytd_data.Description.str.contains("CYANFACE", case=False), 'Short_Desc'] = 'Jayelin'
ytd_data.loc[ytd_data.Description.str.contains("Michaels", case=False), 'Short_Desc'] = 'moving'
ytd_data.loc[ytd_data.Description.str.contains("INSTACART", case=False), 'Short_Desc'] = 'groceries'
ytd_data.loc[ytd_data.Description.str.contains("SCOTTSDALE Q SCOTTSDALE", case=False), 'Short_Desc'] = 'coffee'
ytd_data.loc[ytd_data.Description.str.contains("Finance Plus", case=False), 'Short_Desc'] = 'professional'
ytd_data.loc[ytd_data.Description.str.contains("HARVARD BUS", case=False), 'Short_Desc'] = 'professional'
ytd_data

# Nov 2022
ytd_data.loc[ytd_data.Description.str.contains("Obsidian", case=False), 'Short_Desc'] = 'learning'
ytd_data.loc[ytd_data.Description.str.contains("u-haul", case=False), 'Short_Desc'] = 'moving'
ytd_data.loc[ytd_data.Description.str.contains("taskrabbit", case=False), 'Short_Desc'] = 'moving'
ytd_data.loc[ytd_data.Description.str.contains("wework", case=False), 'Short_Desc'] = 'professional'
ytd_data.loc[ytd_data.Description.str.contains("extra space", case=False), 'Short_Desc'] = 'storage'
ytd_data.loc[ytd_data.Description.str.contains("uniqlo", case=False), 'Short_Desc'] = 'clothing'
ytd_data.loc[ytd_data.Description.str.contains("RISE PIZZERIA BURLINGAME", case=False), 'Short_Desc'] = 'restaurant'
ytd_data.loc[ytd_data.Description.str.contains("ICICLES - MOUNTAIN MOUNTAIN VIEWCA", case=False), 'Short_Desc'] = 'restaurant'
ytd_data.loc[ytd_data.Description.str.contains("URBAN RITUAL SAN MATEO", case=False), 'Short_Desc'] = 'restaurant'
ytd_data.loc[ytd_data.Description.str.contains("URBAN RITUAL SAN MATEO", case=False), 'Short_Desc'] = 'restaurant'
ytd_data.loc[ytd_data.Description.str.contains("SALT & STRAW SAN JOSE", case=False), 'Short_Desc'] = 'restaurant'
ytd_data.loc[ytd_data.Description.str.contains("ROYAL DONUT BURLINGAME", case=False), 'Short_Desc'] = 'restaurant'
ytd_data.loc[ytd_data.Description.str.contains("OLDE TYME KETTLE K FRESNO", case=False), 'Short_Desc'] = 'restaurant'
ytd_data.loc[ytd_data.Description.str.contains("OCEANIC FOOT SPA BURLINGAME", case=False), 'Short_Desc'] = 'restaurant'
ytd_data.loc[ytd_data.Description.str.contains("GOTHAM ENTERPRISE SAN", case=False), 'Short_Desc'] = 'restaurant'
ytd_data.loc[ytd_data.Description.str.contains("GELATAIO SAN CARLOS", case=False), 'Short_Desc'] = 'restaurant'
ytd_data.loc[ytd_data.Description.str.contains("CHERIMOYA BURLINGAME", case=False), 'Short_Desc'] = 'restaurant'
ytd_data.loc[ytd_data.Description.str.contains("FRANK GRIZZLY", case=False), 'Short_Desc'] = 'restaurant'
ytd_data.loc[ytd_data.Description.str.contains("ARIZMENDI BAKERY C SAN", case=False), 'Short_Desc'] = 'restaurant'
ytd_data.loc[ytd_data.Description.str.contains("WAHLBURGERS BURLINGAME BURLINGAME CA", case=False), 'Short_Desc'] = 'restaurant'
ytd_data.loc[ytd_data.Description.str.contains("CREPEVINE", case=False), 'Short_Desc'] = 'restaurant'
ytd_data.loc[ytd_data.Description.str.contains("RASPADOS Y ANTOJITAS LA", case=False), 'Short_Desc'] = 'restaurant'
ytd_data.loc[ytd_data.Description.str.contains("Best Buy", case=False), 'Short_Desc'] = 'electronics'
ytd_data.loc[ytd_data.Description.str.contains("ANCHOR PUBLIC TAPS SAN FRANCISCOCA", case=False), 'Short_Desc'] = 'restaurant'
ytd_data.loc[ytd_data.Description.str.contains("ASIAN BOX BURLINGAME CA", case=False), 'Short_Desc'] = 'restaurant'
ytd_data.loc[ytd_data.Description.str.contains("AYTTHAYA THAI SEATTLE WA", case=False), 'Short_Desc'] = 'restaurant'
ytd_data.loc[ytd_data.Description.str.contains("OLD SPAGHETTI FACTORY", case=False), 'Short_Desc'] = 'restaurant'
ytd_data.loc[ytd_data.Description.str.contains("SOL SCOTTSDALE", case=False), 'Short_Desc'] = 'restaurant'
ytd_data.loc[ytd_data.Description.str.contains("KJ'S BAR SEATTLE", case=False), 'Short_Desc'] = 'restaurant'
ytd_data.loc[ytd_data.Description.str.contains("HONG KONG BANJUM PAIK'S", case=False), 'Short_Desc'] = 'restaurant'
ytd_data.loc[ytd_data.Description.str.contains("HAN SUNG BBQ", case=False), 'Short_Desc'] = 'restaurant'
ytd_data.loc[ytd_data.Description.str.contains("ALHAMBRA IRISH HOUSE", case=False), 'Short_Desc'] = 'restaurant'
ytd_data.loc[ytd_data.Description.str.contains("WILEY", case=False), 'Short_Desc'] = 'learning'
ytd_data.loc[ytd_data.Description.str.contains("USPS", case=False), 'Short_Desc'] = 'moving'
ytd_data.loc[ytd_data.Description.str.contains("URBAN MKT CONCOURSE D", case=False), 'Short_Desc'] = 'restaurant'
ytd_data.loc[ytd_data.Description.str.contains("JACK'S FISH SPOT", case=False), 'Short_Desc'] = 'restaurant'
ytd_data.loc[ytd_data.Description.str.contains("LEETCODE", case=False), 'Short_Desc'] = 'leet_code'
ytd_data.loc[ytd_data.Description.str.contains("SPORTSLINE", case=False), 'Short_Desc'] = 'sports_line'
ytd_data.loc[ytd_data.Description.str.contains("THE PLANING MILL", case=False), 'Short_Desc'] = 'restaurant'
ytd_data.loc[ytd_data.Description.str.contains("KFC", case=False), 'Short_Desc'] = 'fast_food'
ytd_data.loc[ytd_data.Description.str.contains("HABIT", case=False), 'Short_Desc'] = 'restaurant'
ytd_data.loc[ytd_data.Description.str.contains("GREEN TORTOISE HOSTEL", case=False), 'Short_Desc'] = 'hostel'
ytd_data.loc[ytd_data.Description.str.contains("THE NEW STAND", case=False), 'Short_Desc'] = 'restaurant'
ytd_data.loc[ytd_data.Description.str.contains("STANFORDSTADIUMCONCESSIO", case=False), 'Short_Desc'] = 'fast_food'
ytd_data.loc[ytd_data.Description.str.contains("SP DROP.COM", case=False), 'Short_Desc'] = 'electronics'
ytd_data.loc[ytd_data.Description.str.contains("SKYLINE NEWS AND GIFTS", case=False), 'Short_Desc'] = 'airport'
ytd_data.loc[ytd_data.Description.str.contains("SFO THE PLANT", case=False), 'Short_Desc'] = 'restaurant'
ytd_data.loc[ytd_data.Description.str.contains("EPIC GAMES", case=False), 'Short_Desc'] = 'video_games'
ytd_data.loc[ytd_data.Description.str.contains("COURSE HERO", case=False), 'Short_Desc'] = 'learning'
ytd_data.loc[ytd_data.Description.str.contains("OFFICE DEPOT", case=False), 'Short_Desc'] = 'home_supplies'
ytd_data.loc[ytd_data.Description.str.contains("BHSM REHABILITATIO", case=False), 'Short_Desc'] = 'medical'
ytd_data.loc[ytd_data.Description.str.contains("JACK IN THE BOX", case=False), 'Short_Desc'] = 'fast_food'
ytd_data.loc[ytd_data.Description.str.contains("HYATT REG PHOENIX F&B", case=False), 'Short_Desc'] = 'restaurant'
ytd_data.loc[ytd_data.Description.str.contains("FLIGHTS BURLINGAME", case=False), 'Short_Desc'] = 'restaurant'
ytd_data.loc[ytd_data.Description.str.contains("COCOLA", case=False), 'Short_Desc'] = 'restaurant'
ytd_data.loc[ytd_data.Description.str.contains("FUEL 24 7 WESTBOROUGH", case=False), 'Short_Desc'] = 'gas_station'
ytd_data.loc[ytd_data.Description.str.contains("MAIDO STATIONERY", case=False), 'Short_Desc'] = 'home_supplies'
ytd_data.loc[ytd_data.Description.str.contains("GOOGLE \*YT PRIMETIME", case=False), 'Short_Desc'] = 'youtube'
ytd_data.loc[ytd_data.Description.str.contains("CKE\*SOM TUM STATION", case=False), 'Short_Desc'] = 'restaurant'
ytd_data.loc[ytd_data.Description.str.contains("\*HOWIE'S ARTISAN PIZZ", case=False), 'Short_Desc'] = 'restaurant'
ytd_data.loc[ytd_data.Description.str.contains("CHUKAR CHERRY COMPANY", case=False), 'Short_Desc'] = 'restaurant'
ytd_data.loc[ytd_data.Description.str.contains("BRUNDAVAN INDIAN CUISINE", case=False), 'Short_Desc'] = 'restaurant'
ytd_data.loc[ytd_data.Description.str.contains("CINEPOLIS", case=False), 'Short_Desc'] = 'movies'
ytd_data.loc[ytd_data.Description.str.contains("APPLE FRITTER", case=False), 'Short_Desc'] = 'restaurant'
ytd_data.loc[ytd_data.Description.str.contains("FEDEX", case=False), 'Short_Desc'] = 'mailing'
ytd_data.loc[ytd_data.Description.str.contains("ALLIANZ TRAVEL INS", case=False), 'Short_Desc'] = 'air_travel'
ytd_data.loc[ytd_data.Description.str.contains("712 GARAGE LANES", case=False), 'Short_Desc'] = 'bowling'
ytd_data.loc[ytd_data.Description.str.contains("DIMOND FOOD MART LLC", case=False), 'Short_Desc'] = 'gas_station'
ytd_data.loc[ytd_data.Description.str.contains("DEAN'S PRODUCE", case=False), 'Short_Desc'] = 'groceries'
ytd_data.loc[ytd_data.Description.str.contains("FIVE BELOW", case=False), 'Short_Desc'] = 'five_below'
ytd_data.loc[ytd_data.Description.str.contains("BED BATH", case=False), 'Short_Desc'] = 'bed_bath_and_beyond'
ytd_data.loc[ytd_data.Description.str.contains("BIG 5 SPORTING GOODS", case=False), 'Short_Desc'] = 'big_5_sporting_goods'
ytd_data.loc[ytd_data.Description.str.contains("INMOTION-814", case=False), 'Short_Desc'] = 'restaurant'
ytd_data.loc[ytd_data.Description.str.contains("apple", case=False) & (ytd_data['Amount'] == 553.89), 'Short_Desc'] = 'iphone_14'
ytd_data.loc[ytd_data.Description.str.contains("apple", case=False) & (ytd_data['Amount'] == 53.72), 'Short_Desc'] = 'iphone_case'
ytd_data.loc[ytd_data.Description.str.contains("apple", case=False) & (ytd_data['Amount'] == 76.31), 'Short_Desc'] = 'the_athletic'
ytd_data.loc[ytd_data.Description.str.contains("apple", case=False) & (ytd_data['Amount'] == 37.09), 'Short_Desc'] = 'yahoo_fantasy_plus'
ytd_data.loc[ytd_data.Description.str.contains("apple", case=False) & (ytd_data['Amount'] == 9.99), 'Short_Desc'] = 'apple_care'

# %%
ytd_data.loc[ytd_data.Short_Desc.isin(['home','home_supplies','hostel']), 'Category_2'] = 'Housing'
ytd_data.loc[ytd_data.Short_Desc.isin(['ride_share','gas_station','parking','air_travel','airport','bus_fare']), 'Category_2'] = 'Transportation'
ytd_data.loc[ytd_data.Short_Desc.isin(['fast_food', 'restaurant', 'groceries','coffee','work_lunch']), 'Category_2'] = 'Food'
ytd_data.loc[ytd_data.Short_Desc.isin(['state_farm']), 'Category_2'] = 'Insurance'
ytd_data.loc[ytd_data.Short_Desc.isin(['cell_phone', 'aps','car','storage']), 'Category_2'] = 'Utilities'
ytd_data.loc[ytd_data.Short_Desc.isin(['medical', 'dental']), 'Category_2'] = 'Medical'
ytd_data.loc[ytd_data.Short_Desc.isin([]), 'Category_2'] = 'Savings'
ytd_data.loc[ytd_data.Short_Desc.isin(['conv_store','clothing','learning','staples','target','stretch_zone','bookstore','professional','political_cause','gym','barbershop','wallet','everything_store','walmart','clothes','hair_supplies','bed_bath_and_beyond','amazon','five_below','big_5_sporting_goods','leet_code','sports_line']), 'Category_2'] = 'Personal_Spending'
ytd_data.loc[ytd_data.Short_Desc.isin(['breaking_points', 'spotify','netflix','hulu','viki','nba_league_pass','hbo','crunchy_roll','blossom','meal_lime','apple_tv','grammarly','youtube_tv','nvidia','pay_wall','disney','medium','fubo_tv','onlyfans','oculus','concert','movies','museum','music_festival','live_nba','nvidia','comedy','live_baseball','concerts','hoover_dam','tennis','vr_arcade','video_games','live_event','sport_stuff','zoo','electronics','bowling', 'youtube']), 'Category_2'] = 'Recreation_Entertainment'
ytd_data.loc[ytd_data.Short_Desc.isin(['unsure','vending','moving','mailing']), 'Category_2'] = 'Misc'
ytd_data.loc[ytd_data.Short_Desc.isin(['tahjei','don','dad', 'Jayelin']), 'Category_2'] = 'People'
ytd_data.loc[ytd_data.Short_Desc.isin(['payment','interest','cashback_bonus']), 'Category_2'] = 'Payment_and_Interest'
